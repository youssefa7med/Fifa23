# %% [markdown]
# ![](fifa23.png)

# %% [markdown]
# ## About Dataset
# * FIFA 23 is a football simulation video game published by Electronic Arts. It is the 30th and final installment in the FIFA series that is developed by EA Sports, and released worldwide on 30 September 2022 for PC, Nintendo Switch, PlayStation 4, PlayStation 5, Xbox One, Xbox Series X/S and Google Stadia.
#
# * The role of performance analysis within football is more important than ever. Whether it’s the opposition, potential transfer targets or last weekend’s fixture, analysing performances and data can be the difference between success and failure.
#
# #### https://www.kaggle.com/datasets/sanjeetsinghnaik/fifa-23-players-dataset

# %%
import pandas as pd 
import numpy  as np
import plotly.express as px
from plotly.offline import plot, iplot

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r"E:\data science\note.books\Full projects\Fifa 19\Fifa_23.csv")

# %%
df.head()
# Out:
#          Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions Played Best Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image Link  Age  Height(in cm)  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35            169
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34            185
# ...

# %%
df.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18539 entries, 0 to 18538
# Data columns (total 89 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Known As                     18539 non-null  object
#  1   Full Name                    18539 non-null  object
#  2   Overall                      18539 non-null  int64
#  3   Potential                    18539 non-null  int64
#  4   Value(in Euro)               18539 non-null  int64
#  5   Positions Played             18539 non-null  object
#  6   Best Position                18539 non-null  object
#  7   Nationality                  18539 non-null  object
#  8   Image Link                   18539 non-null  object
#  9   Age                          18539 non-null  int64
#  10  Height(in cm)                18539 non-null  int64
#  11  Weight(in kg)                18539 non-null  int64
#  12  TotalStats                   18539 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# Known As                       0
# Full Name                      0
# Overall                        0
# Potential                      0
# Value(in Euro)                 0
# Positions Played               0
# Best Position                  0
# Nationality                    0
# Image Link                     0
# Age                            0
# Height(in cm)                  0
# Weight(in kg)                  0
# TotalStats                     0
# BaseStats                      0
# Club Name                      0
# Wage(in Euro)                  0
# Release Clause                 0
# Club Position                  0
# Contract Until                 0
# Club Jersey Number             0
# Joined On                      0
# On Loan                        0
# Preferred Foot                 0
# Weak Foot Rating               0
# Skill Moves                    0
# International Reputation       0
# National Team Name             0
# National Team Image Link       0
# ...

# %%
df.duplicated().sum()
# Out:
# 119

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#             Overall     Potential  Value(in Euro)           Age  \
# count  18420.000000  18420.000000    1.842000e+04  18420.000000
# mean      65.792942     70.963301    2.842697e+06     25.243920
# std        6.770177      6.170634    7.645260e+06      4.725456
# min       47.000000     48.000000    0.000000e+00     16.000000
# 25%       62.000000     67.000000    4.750000e+05     21.000000
# 50%       66.000000     71.000000    9.750000e+05     25.000000
# 75%       70.000000     75.000000    2.000000e+06     29.000000
# max       91.000000     95.000000    1.905000e+08     44.000000
#
#        Height(in cm)  Weight(in kg)   TotalStats     BaseStats  Wage(in Euro)  \
# count   18420.000000   18420.000000  18420.00000  18420.000000   18420.000000
# mean      181.550814      75.170141   1600.67139    357.650543    8733.099891
# std         6.855181       7.006937    272.81089     39.541870   19452.416115
# ...

# %%
df.describe(include='O')
# Out:
#             Known As        Full Name Positions Played Best Position  \
# count          18420            18420            18420         18420
# unique         17530            18337              693            15
# top     A. Rodríguez  Diego Rodríguez               CB            CB
# freq               7                3             2415          3631
#
#        Nationality                                        Image Link  \
# count        18420                                             18420
# unique         160                                             18420
# top        England  https://cdn.sofifa.net/players/158/023/23_60.png
# freq          1624                                                 1
#
#          Club Name Club Position Contract Until Club Jersey Number On Loan  \
# count        18420         18420          18420              18420   18420
# unique         679            20             10                100       2
# ...

# %%
df.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
# ...

# %%
num_cols = df.select_dtypes(include='number').columns

# %%
num_cols
# Out:
# Index(['Overall', 'Potential', 'Value(in Euro)', 'Age', 'Height(in cm)',
#        'Weight(in kg)', 'TotalStats', 'BaseStats', 'Wage(in Euro)',
#        'Release Clause', 'Joined On', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'Pace Total', 'Shooting Total',
#        'Passing Total', 'Dribbling Total', 'Defending Total',
#        'Physicality Total', 'Crossing', 'Finishing', 'Heading Accuracy',
#        'Short Passing', 'Volleys', 'Dribbling', 'Curve', 'Freekick Accuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'Sprint Speed', 'Agility',
#        'Reactions', 'Balance', 'Shot Power', 'Jumping', 'Stamina', 'Strength',
#        'Long Shots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeper Diving', 'Goalkeeper Handling',
#        ' GoalkeeperKicking', 'Goalkeeper Positioning', 'Goalkeeper Reflexes',
# ...

# %%
cat_cols = df.select_dtypes(include='O').columns

# %%
cat_cols
# Out:
# Index(['Known As', 'Full Name', 'Positions Played', 'Best Position',
#        'Nationality', 'Image Link', 'Club Name', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'On Loan', 'Preferred Foot',
#        'National Team Name', 'National Team Image Link',
#        'National Team Position', 'National Team Jersey Number',
#        'Attacking Work Rate', 'Defensive Work Rate'],
#       dtype='object')

# %%
cat_cols
# Out:
# Index(['Known As', 'Full Name', 'Positions Played', 'Best Position',
#        'Nationality', 'Image Link', 'Club Name', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'On Loan', 'Preferred Foot',
#        'National Team Name', 'National Team Image Link',
#        'National Team Position', 'National Team Jersey Number',
#        'Attacking Work Rate', 'Defensive Work Rate'],
#       dtype='object')

# %%
df['Nationality'].value_counts().reset_index().nlargest(10,'Nationality')
# Out:
#            index  Nationality
# 0        England         1624
# 1        Germany         1201
# 2          Spain         1062
# 3         France          953
# 4      Argentina          931
# 5         Brazil          714
# 6          Italy          620
# 7       China PR          439
# 8  United States          435
# 9    Netherlands          426

# %%
iplot(px.bar(df['Nationality'].value_counts().reset_index().nlargest(10,'Nationality')
             ,x='index',y='Nationality',template='simple_white',text_auto=True,color = 'Nationality'
             ,title = 'The barplot about values count in Top 10 of Nationality'))
# Out:
# <div>                            <div id="b9290be3-d45c-4516-83ba-13e3e5be71ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9290be3-d45c-4516-83ba-13e3e5be71ec")) {                    Plotly.newPlot(                        "b9290be3-d45c-4516-83ba-13e3e5be71ec",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Nationality=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[1624,1201,1062,953,931,714,620,439,435,426],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["England","Germany","Spain","France","Argentina","Brazil","Italy","China PR","United States","Netherlands"],"xaxis":"x","y":[1
# ...

# %%
iplot(px.bar(df['Best Position'].value_counts().reset_index().nlargest(10,'Best Position')
             ,x='index',y='Best Position',template='simple_white',text_auto=True,color='Best Position'
             ,title = 'The barplot about values count in Top 10 of Best Position'))
# Out:
# <div>                            <div id="e1645bde-b8e3-42c6-b472-5467f675aa82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1645bde-b8e3-42c6-b472-5467f675aa82")) {                    Plotly.newPlot(                        "e1645bde-b8e3-42c6-b472-5467f675aa82",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Best Position=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[3631,2549,2291,2053,1438,1396,1092,917,860,790],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["CB","ST","CAM","GK","RM","CDM","CM","RB","LB","LM"],"xaxis":"x","y":[3631,2549,2291,2053,1438,1396,1092,917,860,790],"y
# ...

# %%
cat_cols
# Out:
# Index(['Known As', 'Full Name', 'Positions Played', 'Best Position',
#        'Nationality', 'Image Link', 'Club Name', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'On Loan', 'Preferred Foot',
#        'National Team Name', 'National Team Image Link',
#        'National Team Position', 'National Team Jersey Number',
#        'Attacking Work Rate', 'Defensive Work Rate'],
#       dtype='object')

# %%
iplot(px.bar(df['Club Name'].value_counts().reset_index().nlargest(10,'Club Name')
             ,x='index',y='Club Name',template='simple_white',text_auto=True,color='Club Name'
             ,title = 'The barplot about values count in Top 10 of Club Name'))
# Out:
# <div>                            <div id="5f077e94-f352-44e8-928e-f89510c9acc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f077e94-f352-44e8-928e-f89510c9acc2")) {                    Plotly.newPlot(                        "5f077e94-f352-44e8-928e-f89510c9acc2",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Club Name=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[90,33,33,33,33,33,33,33,33,33],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Free agent","Wolverhampton Wanderers","Atl\u00e9tico de Madrid","Borussia Dortmund","Nottingham Forest","Real Madrid CF","Valencia CF","RC C
# ...

# %%
df['Club Name'].unique().shape[0]
# Out:
# 679

# %%
df['Attacking Work Rate'].value_counts().reset_index()
# Out:
#     index  Attacking Work Rate
# 0  Medium                12138
# 1    High                 5409
# 2     Low                  873

# %%
iplot(px.bar(data_frame=df['Attacking Work Rate'].value_counts().reset_index()
       ,x='index',y='Attacking Work Rate',template='simple_white',text_auto=True,color='Attacking Work Rate'
             ,title = 'The barplot about values count of Attacking Work Rate'))
# Out:
# <div>                            <div id="4a18dbba-7433-4d53-920f-3bd63d207c90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a18dbba-7433-4d53-920f-3bd63d207c90")) {                    Plotly.newPlot(                        "4a18dbba-7433-4d53-920f-3bd63d207c90",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Attacking Work Rate=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[12138,5409,873],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Medium","High","Low"],"xaxis":"x","y":[12138,5409,873],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"col
# ...

# %%
iplot(px.bar(data_frame=df['Defensive Work Rate'].value_counts().reset_index()
       ,x='index',y='Defensive Work Rate',template='simple_white',text_auto=True,color='Defensive Work Rate'
             ,title = 'The barplot about values count of Defensive Work Rate'))
# Out:
# <div>                            <div id="db7d1667-ba45-4629-90d4-25ba0884a10c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db7d1667-ba45-4629-90d4-25ba0884a10c")) {                    Plotly.newPlot(                        "db7d1667-ba45-4629-90d4-25ba0884a10c",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Defensive Work Rate=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[13533,3344,1543],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Medium","High","Low"],"xaxis":"x","y":[13533,3344,1543],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"c
# ...

# %%
cat_cols
# Out:
# Index(['Known As', 'Full Name', 'Positions Played', 'Best Position',
#        'Nationality', 'Image Link', 'Club Name', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'On Loan', 'Preferred Foot',
#        'National Team Name', 'National Team Image Link',
#        'National Team Position', 'National Team Jersey Number',
#        'Attacking Work Rate', 'Defensive Work Rate'],
#       dtype='object')

# %%
df[cat_cols].head(1)
# Out:
#    Known As     Full Name Positions Played Best Position Nationality  \
# 0  L. Messi  Lionel Messi               RW           CAM   Argentina
#
#                                          Image Link            Club Name  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png  Paris Saint-Germain
#
#   Club Position Contract Until Club Jersey Number On Loan Preferred Foot  \
# 0            RW           2023                 30       -           Left
#
#   National Team Name             National Team Image Link  \
# 0          Argentina  https://cdn.sofifa.net/flags/ar.png
#
#   National Team Position National Team Jersey Number Attacking Work Rate  \
# 0                     RW                          10                 Low
#
#   Defensive Work Rate
# 0                 Low

# %%
iplot(px.bar(data_frame=df['Preferred Foot'].value_counts().reset_index()
       ,x='index',y='Preferred Foot',template='simple_white',text_auto=True,color='Preferred Foot'
             ,title = 'The barplot about values count of Preferred Foot'))
# Out:
# <div>                            <div id="0551c5b0-bd4c-49a8-8a06-8671759f66e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0551c5b0-bd4c-49a8-8a06-8671759f66e0")) {                    Plotly.newPlot(                        "0551c5b0-bd4c-49a8-8a06-8671759f66e0",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Preferred Foot=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[13951,4469],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Right","Left"],"xaxis":"x","y":[13951,4469],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"te
# ...

# %%
iplot(px.bar(data_frame=df['Weak Foot Rating'].value_counts().reset_index()
       ,x='index',y='Weak Foot Rating',template='simple_white',text_auto=True,color='Weak Foot Rating'
             ,title = 'The barplot about values count of Weak Foot Rating'))
# Out:
# <div>                            <div id="ac31d82c-21fc-43d9-a5d1-5b1440306a03" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac31d82c-21fc-43d9-a5d1-5b1440306a03")) {                    Plotly.newPlot(                        "ac31d82c-21fc-43d9-a5d1-5b1440306a03",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Weak Foot Rating=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[11403,3924,2629,301,163],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":[3,2,4,5,1],"xaxis":"x","y":[11403,3924,2629,301,163],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"
# ...

# %%
iplot(px.bar(data_frame=df['Skill Moves'].value_counts().reset_index()
       ,x='index',y='Skill Moves',template='simple_white',text_auto=True,color='Skill Moves'
             ,title = 'The barplot about values count of Skill Moves'))
# Out:
# <div>                            <div id="157a3d81-beb8-47f6-8af9-ffd4c400100e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("157a3d81-beb8-47f6-8af9-ffd4c400100e")) {                    Plotly.newPlot(                        "157a3d81-beb8-47f6-8af9-ffd4c400100e",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Skill Moves=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[8856,6320,2053,1142,49],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":[2,3,1,4,5],"xaxis":"x","y":[8856,6320,2053,1142,49],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"colorba
# ...

# %%
iplot(px.bar(data_frame=df['International Reputation'].value_counts().reset_index()
       ,x='index',y='International Reputation',template='simple_white',text_auto=True,color='International Reputation'
             ,title = 'The barplot about values count of International Reputation'))
# Out:
# <div>                            <div id="e4d952d9-f6a0-4fbd-8455-1c1b0d1f2d5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4d952d9-f6a0-4fbd-8455-1c1b0d1f2d5f")) {                    Plotly.newPlot(                        "e4d952d9-f6a0-4fbd-8455-1c1b0d1f2d5f",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>International Reputation=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[17216,888,254,55,7],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":[1,2,3,4,5],"xaxis":"x","y":[17216,888,254,55,7],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"co
# ...

# %%
iplot(px.histogram(df,x='Overall',template='simple_white',text_auto=True,color ='Overall'
                   ,title = 'The histogram of Overall'))
# Out:
# <div>                            <div id="a11f18db-19b1-4551-96f5-3befaa69222e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a11f18db-19b1-4551-96f5-3befaa69222e")) {                    Plotly.newPlot(                        "a11f18db-19b1-4551-96f5-3befaa69222e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Overall=%{x}<br>count=%{y}<extra></extra>","legendgroup":"91","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"91","offsetgroup":"91","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":[91,91,91,91,91],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Overall=%{x}<br>count=%{y}<extra></extra>","legendgroup":"90","marker":{"color":"
# ...

# %%
num_cols
# Out:
# Index(['Overall', 'Potential', 'Value(in Euro)', 'Age', 'Height(in cm)',
#        'Weight(in kg)', 'TotalStats', 'BaseStats', 'Wage(in Euro)',
#        'Release Clause', 'Joined On', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'Pace Total', 'Shooting Total',
#        'Passing Total', 'Dribbling Total', 'Defending Total',
#        'Physicality Total', 'Crossing', 'Finishing', 'Heading Accuracy',
#        'Short Passing', 'Volleys', 'Dribbling', 'Curve', 'Freekick Accuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'Sprint Speed', 'Agility',
#        'Reactions', 'Balance', 'Shot Power', 'Jumping', 'Stamina', 'Strength',
#        'Long Shots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeper Diving', 'Goalkeeper Handling',
#        ' GoalkeeperKicking', 'Goalkeeper Positioning', 'Goalkeeper Reflexes',
# ...

# %%
df[num_cols].head()
# Out:
#    Overall  Potential  Value(in Euro)  Age  Height(in cm)  Weight(in kg)  \
# 0       91         91        54000000   35            169             67
# 1       91         91        64000000   34            185             81
# 2       91         91        84000000   33            185             81
# 3       91         91       107500000   31            181             70
# 4       91         95       190500000   23            182             73
#
#    TotalStats  BaseStats  Wage(in Euro)  Release Clause  Joined On  \
# 0        2190        452         195000        99900000       2021
# 1        2147        455         450000       131199999       2009
# 2        2205        458         420000       172200000       2022
# 3        2303        483         350000       198900000       2015
# 4        2177        470         230000       366700000       2018
#
#    Weak Foot Rating  Skill Moves  International Reputation  Pace Total  \
# ...

# %%
def playerlocation(x)
    if x in []
